# %%
import pandas as pd
import numpy as np
import os
import datetime
import plotly
import plotly.graph_objs as go
from pathlib import Path
from itertools import combinations

# %%
from app_container.etl_scripts.df_transform import *
from app_container.etl_scripts.data_wrangle import *
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-592effd8125e> in <module>
# ----> 1 from app_container.etl_scripts.df_transform import *
#       2 from app_container.etl_scripts.data_wrangle import *
#
# ~/Documents/GitHub/anko-dashboard/app_container/__init__.py in <module>
#       3 app = Flask(__name__)
#       4
# ----> 5 from app_container import routes
#
# ~/Documents/GitHub/anko-dashboard/app_container/routes.py in <module>
#      13 import plotly
#      14 from flask import (render_template, request, session, url_for)
# ---> 15 from app_container import etl_scripts as etl
#      16 from app_container.flask_components.input_form import *
#      17 from app_container._input import DATE, DIRTY_DICT
#
# ~/Documents/GitHub/anko-dashboard/app_container/etl_scripts/__init__.py in <module>
# ----> 1 from app_container.etl_scripts.data_plot import *
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
PATH = Path.cwd().resolve() / "dataset"
DATA_PATH = {"UK": PATH / "UK", "GROUP": PATH / "GROUP"}

data_list = {name: os.listdir(path) for name, path in DATA_PATH.items()}

# %%
data_list = {name: os.listdir(path) for name, path in DATA_PATH.items()}

# %%
DATA_PATH = {"UK": r"dataset/UK/", "GROUP": r"dataset/GROUP/"}

# %%
df_uk = dict()
df_group = dict()
for key, item in data_list.items():
    for file in item:
        date = file.split(".")[0]
        _df = pd.read_excel(DATA_PATH[key] +f"{file}", skiprows=2)
        # UK / Group separation.
        if key == "GROUP":
            df_group[f"{date}"] = data_preprocess(_df)
        else:
            df_uk[f"{date}"] = data_preprocess(_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b185ba33731a> in <module>
#       1 df_uk = dict()
#       2 df_group = dict()
# ----> 3 for key, item in data_list.items():
#       4     for file in item:
#       5         date = file.split(".")[0]
#
# NameError: name 'data_list' is not defined

# %%
date_list = ["4Q19", "2Q20", "4Q20"]

# %%
firm_list = ["Barclays - UK", "HSBC - UK", "Lloyds - Underlying", "NatWest Bank PLC"]

# %%
portfolios = [
    "Total Loans & Advances", "Mortgages",
    "Consumer Lending (including Auto Finance)", "Corporate & Commercial"
]

# %%
xy = pivot_transform_df(df_uk, date_list, firm_list, agg_ecl_df)

# %%
xz = df_filter(xy, firm_list, portfolios)

# %%
list(combinations(xz.columns.get_level_values(0).unique(), 2))
# Out:
# [(Timestamp('2019-12-01 00:00:00'), Timestamp('2020-06-01 00:00:00')),
#  (Timestamp('2019-12-01 00:00:00'), Timestamp('2020-12-01 00:00:00')),
#  (Timestamp('2020-06-01 00:00:00'), Timestamp('2020-12-01 00:00:00'))]

# %%
output = relative_change_df(df_uk, date_list, firm_list, portfolios, agg_ecl_df)

# %%
output
# Out:
# pandas.core.frame.DataFrame

# %%
items = output.columns.get_level_values(0).unique()[::-1]

# %%
items
# Out:
# Index(['2020-Q4 vs 2020-Q2', '2020-Q4 vs 2019-Q4', '2020-Q2 vs 2019-Q4'], dtype='object')

# %%
df_one = output[["2020-Q2 vs 2019-Q4"]]

# %%
df_one.columns = df_one.columns.get_level_values(1)

# %%
fig = mult_bar_chart_produce(output, "% change")

# %%
fig[0]
# Out:
# <div>                            <div id="9c4a4486-6e76-4c89-b6ae-b77777879e96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c4a4486-6e76-4c89-b6ae-b77777879e96")) {                    Plotly.newPlot(                        "9c4a4486-6e76-4c89-b6ae-b77777879e96",                        [{"name": "Consumer Lending (including Auto Finance)", "type": "bar", "x": ["Barclays - UK", "HSBC - UK", "Lloyds - Underlying", "NatWest Bank PLC"], "y": [-0.0805040252012601, 0.1279373368146215, 0.0632743362831858, -0.09967585089141007]}, {"name": "Corporate & Commercial", "type": "bar", "x": ["Barclays - UK", "HSBC - UK", "Lloyds - Underlying", "NatWest Bank PLC"], "y": [0.21511627906976738, 0.1954459203036054, -0.12591240875912413, -0.005895691609977272]}, {"n
# ...

# %%
AGG_FUNC_DICT
# Out:
# {'ECL': <function app_container.etl_scripts.df_transform.agg_ecl_df(df: pandas.core.frame.DataFrame) -> pandas.core.frame.DataFrame>,
#  'Stage 2 Balance': <function app_container.etl_scripts.df_transform.agg_st2_df(df: pandas.core.frame.DataFrame) -> pandas.core.frame.DataFrame>,
#  'Stage 3 Balance': <function app_container.etl_scripts.df_transform.agg_st3_df(df: pandas.core.frame.DataFrame) -> pandas.core.frame.DataFrame>,
#  'Coverage': <function app_container.etl_scripts.df_transform.agg_coverage_df(df: pandas.core.frame.DataFrame) -> pandas.core.frame.DataFrame>}

# %%
from app_container import etl_scripts as etl

# %%
aa = etl.df_extract("UK", date_list)

# %%
mult_bar_chart_produce(relative_change_df(aa, date_list, firm_list, portfolios, agg_ecl_df), "a")[0]
# Out:
# <div>                            <div id="50956987-71de-4ed3-85bb-23e3164ad38a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50956987-71de-4ed3-85bb-23e3164ad38a")) {                    Plotly.newPlot(                        "50956987-71de-4ed3-85bb-23e3164ad38a",                        [{"name": "Consumer Lending (including Auto Finance)", "type": "bar", "x": ["Barclays - UK", "HSBC - UK", "Lloyds - Underlying", "NatWest Bank PLC"], "y": [-0.0805040252012601, 0.1279373368146215, 0.0632743362831858, -0.09967585089141007]}, {"name": "Corporate & Commercial", "type": "bar", "x": ["Barclays - UK", "HSBC - UK", "Lloyds - Underlying", "NatWest Bank PLC"], "y": [0.21511627906976738, 0.1954459203036054, -0.12591240875912413, -0.005895691609977272]}, {"n
# ...
